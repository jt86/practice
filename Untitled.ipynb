# %%
import MultitaskLearning

# %%
MultitaskLearning.run_mtl(3200, 0.0001, 1, 'rfe', 300, 0)
# Out:
# 0
# train shape (241, 40246) test shape (28, 40246)
# means (40246,)
# nor tr (241, 300) nor te (28, 300) pri tr (241, 39946) pri te (28, 39946)
# 39946
# 300
# 300
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-4a86435df885> in <module>()
# ----> 1 MultitaskLearning.run_mtl(3200, 0.0001, 1, 'rfe', 300, 0)
#
# /Users/joe/PycharmProjects/practice/MultitaskLearning.py in run_mtl(num_hidden_units, rate, weight, featsel, num_unsel_feats, foldnum, num_datasets)
#     226             dims = x_tr.shape[0]
#     227             parameters = model(s, x_tr, y_tr1, y_tr2, x_te, y_te1, y_te2, dims, num_unsel_feats, results_file,
# --> 228                                task_2_weight=weight, num_hidden_units=num_hidden_units, learning_rate=rate)
#     229 #
#     230 # for featsel in ['rfe']:#,'anova','bahsic','chi2','mi']:
#
# ...
